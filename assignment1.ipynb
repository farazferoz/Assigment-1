# %% [markdown]
# 1

# %%
num = int(input("Enter a num: "))
if num > 0:
    if num < 10:
        print("It is a single digit num.")
    elif num < 100:
        print("It is a double digit num.")
    elif num < 1000:
        print("It is a three digit num.")
    else:
        print("The num has four or more digits.")
else:
    if num == 0:
        print("The num is zero (not positive).")
    else:
        print("The num is negative.")
# Out:
# It is a double digit num.

# %% [markdown]
# 2

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
num3 = float(input("Enter third number: "))

if (num1 <= num2) and (num1 <= num3):
    smallest = num1
elif (num2 <= num1) and (num2 <= num3):
    smallest = num2
else:
    smallest = num3

print(f"The smallest number is: {smallest}")
# Out:
# The smallest number is: 65.0
